# %% [markdown]
# ## Alarmy Model Training:

# %% [markdown]
# The following notebook is utilised to cover the training and evaluation of our model parameters.

# %%
#!pip install -U ultralytics #uncomment when needing to install. 
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.235 🚀 Python-3.10.18 torch-2.9.1 CPU (Apple M2)
# Setup complete ✅ (8 CPUs, 8.0 GB RAM, 162.6/228.3 GB disk)

# %%
from ultralytics import YOLO


model = YOLO('yolo11n.yaml')

results = model.train(data="/Users/galbraithlee/Downloads/modelled yolo images", epochs=3)
